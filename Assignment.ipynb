# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Wai Min Aung

# %% [markdown]
# _I'm interested in data science because I want to land a job._

# %% [markdown]
# ### It will print "Hello World"

# %%
print ('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# - one
# - two
# - three
#
#
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
#
# https://www.coursera.org/
